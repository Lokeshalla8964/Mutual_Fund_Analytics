# %%
import pandas as pd

sip_data = pd.read_csv("../data/processed/08_investor_transactions_cleaned.csv")

sip_data.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       REDEMPTION      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          LUMPSUM        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   VERIFIED
# 1       Cheque   VERIFIED
# ...

# %% [markdown]
# # Mutual Fund Analytics – Performance Analytics
#
# ## Capstone Project
# ### Bluestock FinTech Internship

# %% [markdown]
# ## Introduction
#
# This notebook evaluates the performance of mutual fund schemes using historical NAV data. Various financial metrics such as Daily Returns, CAGR, Sharpe Ratio, Sortino Ratio, Alpha, Beta, and Maximum Drawdown are calculated to compare the performance of different mutual funds and assess investment risk.

# %% [markdown]
# ## Performance Metrics Calculated
#
# - Daily Returns
# - CAGR (1 Year)
# - CAGR (3 Years)
# - CAGR (5 Years)
# - Sharpe Ratio
# - Sortino Ratio
# - Alpha
# - Beta
# - Maximum Drawdown

# %% [markdown]
# ## Outputs Generated
#
# - fund_scorecard.csv
# - alpha_beta.csv
# - benchmark_comparison.png
# - sharpe.png
# - sortino.png
# - maximum_drawdown.png

# %% [markdown]
# ## Conclusion
#
# The performance analysis demonstrates the return and risk characteristics of different mutual fund schemes. Metrics such as Sharpe Ratio, Sortino Ratio, Alpha, Beta, and Maximum Drawdown provide valuable insights for evaluating investment performance and comparing funds against benchmark indices.
